# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df =pd.read_excel('C:\\Users\\bmoyo\\Documents\\My Projects\\Financial Sample.xlsx')
df.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera          None      1618.5
# 1  Government  Germany  Carretera          None      1321.0
# 2   Midmarket   France  Carretera          None      2178.0
# 3   Midmarket  Germany  Carretera          None       888.0
# 4   Midmarket   Mexico  Carretera          None      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# ...

# %%
df.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount Band', 'Units Sold',
#        'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts',
#        ' Sales', 'COGS', 'Profit', 'Date', 'Month Number', 'Month Name',
#        'Year'],
#       dtype='object')

# %%
df['Product'].value_counts()
# Out:
# Paseo        202
# Velo         109
# VTT          109
# Amarilla      94
# Montana       93
# Carretera     93
# Name: Product, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Country', y=' Sales', data=df, palette='summer_r');

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Product', data=df)
# Out:
# <AxesSubplot:xlabel='Product', ylabel='count'>

# %%
plt.figure(figsize=(10,5));
plt.title('Grace in learning with Didier');
plt.xlabel('product Category')
plt.ylabel('product Count')
# Out:
# Text(3.549999999999997, 0.5, 'product Count')

# %%
plt.figure(figsize=(20,5))
sns.catplot(x='Country', y=' Sales', data= df, kind='box')

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x='Date', y=' Sales', data= df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel=' Sales'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='Product', hue='Country', data= df);
plt.legend();

# %%
sns.kdeplot(x=' Sales', data=df)
# Out:
# <AxesSubplot:xlabel=' Sales', ylabel='Density'>

# %%
sns.histplot(x=' Sales', data=df, kde=True);

# %%
### choice of Visualisation depends on what you want to  visualize

sns.stripplot(x="Product", y="COGS", data=df)
# Out:
# <AxesSubplot:xlabel='Product', ylabel='COGS'>

# %%
sns.violinplot(x="Product", y=" Sales", data=df);

# %%
sns.scatterplot(x="COGS", y=" Sales", data=df);

# %%
df.loc[:,["COGS", " Sales"]].corr()
# Out:
#             COGS     Sales
# COGS    1.000000  0.992244
#  Sales  0.992244  1.000000

# %%
a = list(df['Product'].value_counts().values)
b = list(df['Product'].value_counts().index)

# %%
sns.pairplot(df)

# %%
df.shape
# Out:
# (700, 16)

# %%
pd.crosstab(df['Product'], df['Country'], values=df[' Sales'], aggfunc='sum')
# Out:
# Country         Canada       France     Germany      Mexico  \
# Product
# Amarilla   3855765.875  4016427.130  3960250.26  3077555.39
# Carretera  2610204.340  3423321.895  3062340.68  2879601.42
# Montana    2711919.030  3527382.370  3566044.37  1941329.31
# Paseo      7611520.990  5597751.060  5229814.74  7627731.39
# VTT        4768754.310  3811193.590  3293983.77  3172396.71
# Velo       3329490.340  3978096.235  4392907.00  2250737.89
#
# Country    United States of America
# Product
# Amarilla                2837117.405
# Carretera               1839839.550
# Montana                 3644126.800
# Paseo                   6944325.770
# VTT                     5465592.640
# Velo                    4298828.000

# %%
df.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount Band', 'Units Sold',
#        'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts',
#        ' Sales', 'COGS', 'Profit', 'Date', 'Month Number', 'Month Name',
#        'Year'],
#       dtype='object')

# %%
pd.pivot_table(index=['Country', 'Product'], columns=['Segment'], values=[' Sales'], data=df, aggfunc='sum')
# Out:
#                                               Sales                           \
# Segment                            Channel Partners   Enterprise  Government
# Country                  Product
# Canada                   Amarilla          67177.56   371647.500  2579791.79
#                          Carretera        110610.24   356716.250  1332156.65
#                          Montana           55561.32   376312.500   829859.91
#                          Paseo            165020.04   965142.500  3956873.45
#                          VTT               58479.66  1104828.750   667982.25
#                          Velo              34315.32   792843.750  1374572.47
# France                   Amarilla          43259.28   392952.500  2686041.50
#                          Carretera         65787.12  1187520.625  1397091.15
#                          Montana           48264.36   367282.500  1140656.71
#                          Paseo            108600.78  1250380.000  2532864.68
# ...

# %% [markdown]
# outlier = 1.5 * IQR
#
# or
#
# $$\mu + 3\sigma$$

# %%
q1, q3 = df[' Sales'].quantile(0.25), df[' Sales'].quantile(0.75)

# %%
IQR = q3 - q1

val = 1.5*IQR

# %%
df[df[' Sales']>val]
# Out:
#             Segment                   Country    Product Discount Band  \
# 5        Government                   Germany  Carretera          None
# 26       Government                    Canada      Paseo          None
# 30       Government                   Germany      Paseo          None
# 38   Small Business                    Canada        VTT          None
# 42       Government                    France        VTT          None
# ..              ...                       ...        ...           ...
# 673      Government                    Mexico      Paseo          High
# 678      Government  United States of America      Paseo          High
# 679      Government                    Mexico      Paseo          High
# 685  Small Business  United States of America       Velo          High
# 695  Small Business                    France   Amarilla          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
plt.figure(figsize=(5,3))
sns.boxplot(x=' Sales', data=df, hue='Segment')
# Out:
# <AxesSubplot:xlabel=' Sales'>

# %%
pd.__version__
# Out:
# '1.2.3'

# %%
# Question
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Segment, Country, Product, Discount Band, Units Sold, Manufacturing Price, Sale Price, Gross Sales, Discounts,  Sales, COGS, Profit, Date, Month Number, Month Name, Year]
# Index: []

# %%
file2 = 'C:\\Users\\bmoyo\\Documents/CHAI/Dashboard/Consolidation  Reports of invoices as of 31 March 2021.xlsx'
s2 = 'Database'

# %%
ddf = pd.read_excel(file2, sheet_name=s2)

# %%
ddf[ddf.duplicated()]
# Out:
# Empty DataFrame
# Columns: [No, HFs, CATEGORY, DISTRICT, PROVINCE, PERIOD OF INVOICE, NUMBER OF VOUCHERS, AMOUNT BILLED, AMOUNT AFTER RECONCILIATION, RECEPTION DATE, VERIFICATION DATE, RECONCILIATION DATE, TRANSMISSION DATE FROM SECTION/HOSPITAL TO RSSB BY PROVIDERS, TRANSMISSION DATE FROM RSSB TO RSSB HQ, DATE OF REPORT, Unnamed: 15, OBSERVATIONS, COMMENTS/BORDEREAU, Unnamed: 18, Unnamed: 19]
# Index: []

# %%
ddf[ddf['RECONCILIATION DATE'].isnull( )== True]
# Out:
#         No                    HFs CATEGORY  DISTRICT          PROVINCE  \
# 6        7       AVEGA NTARAMA HC       HC  BUGESERA  EASTERN PROVINCE
# 7        8       AVEGA NTARAMA HC       HC  BUGESERA  EASTERN PROVINCE
# 14      15          BAHO KANZENZE      HPP  BUGESERA  EASTERN PROVINCE
# 15      16          BAHO KANZENZE      HPP  BUGESERA  EASTERN PROVINCE
# 22      23               BUSHENYI       HP  BUGESERA  EASTERN PROVINCE
# ...    ...                    ...      ...       ...               ...
# 8609  8610           NYABIRASI CS       HC   RUTSIRO  WESTERN PROVINCE
# 8617  8618  NYABIRASI HEALTH POST      OFH   RUTSIRO  WESTERN PROVINCE
# 8628  8629             RUTSIRO CS       HC   RUTSIRO  WESTERN PROVINCE
# 8638  8639     RWUMBA HEALTH POST      OFH   RUTSIRO  WESTERN PROVINCE
# 8646  8647    SHYEMBE HEALTH POST      HPP   RUTSIRO  WESTERN PROVINCE
#
#      PERIOD OF INVOICE  NUMBER OF VOUCHERS  AMOUNT BILLED  \
# ...

# %%
df.
